# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/EDVai_DE/blob/main/EDVai_Examen_final/Ejercicio_01/Notebook_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. Create Dataframe from: csv file (Drive, Github, Databricks-Datalake)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path_2021 = 'https://raw.githubusercontent.com/alexandergribenchenko/EDVai_DE/main/EDVai_Examen_final/Ejercicio_01/data/2021-informe-ministerio.csv'
path_2022 = 'https://raw.githubusercontent.com/alexandergribenchenko/EDVai_DE/main/EDVai_Examen_final/Ejercicio_01/data/202206-informe-ministerio.csv'
path_aeropuertos = 'https://raw.githubusercontent.com/alexandergribenchenko/EDVai_DE/main/EDVai_Examen_final/Ejercicio_01/data/aeropuertos_detalle.csv'

# %%
df_2021 = pd.read_csv(path_2021, sep=';')
df_2022 = pd.read_csv(path_2022, sep=';')
df_aeropuertos = pd.read_csv(path_aeropuertos, sep=';')
# Out:
# <ipython-input-22-f95db4416b7d>:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv(path_2022, sep=';')

# %%
df_2021
# Out:
#              Fecha Hora UTC     Clase de Vuelo (todos los vuelos)  \
# 0       01/01/2021    00:02  Vuelo Privado con Matrícula Nacional
# 1       01/01/2021    00:24                               Regular
# 2       01/01/2021    00:26                               Regular
# 3       01/01/2021    00:29                               Regular
# 4       01/01/2021    00:37                               Regular
# ...            ...      ...                                   ...
# 328131  31/12/2021    23:44                               Regular
# 328132  31/12/2021    23:45                               Regular
# 328133  31/12/2021    23:48                               Regular
# 328134  31/12/2021    23:55                               Regular
# 328135  31/12/2021    23:58                               Regular
#
#        Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0                Domestico           Despegue        PAR              ROS
# ...

# %%
list(df_2021.columns)
# Out:
# ['Fecha',
#  'Hora UTC',
#  'Clase de Vuelo (todos los vuelos)',
#  'Clasificación Vuelo',
#  'Tipo de Movimiento',
#  'Aeropuerto',
#  'Origen / Destino',
#  'Aerolinea Nombre',
#  'Aeronave',
#  'Pasajeros',
#  'Calidad dato']

# %%
list(df_2022.columns)
# Out:
# ['Fecha',
#  'Hora UTC',
#  'Clase de Vuelo (todos los vuelos)',
#  'Clasificación Vuelo',
#  'Tipo de Movimiento',
#  'Aeropuerto',
#  'Origen / Destino',
#  'Aerolinea Nombre',
#  'Aeronave',
#  'Pasajeros',
#  'Calidad dato']

# %%
list(df_aeropuertos.columns)
# Out:
# ['local',
#  'oaci',
#  'iata',
#  'tipo',
#  'denominacion',
#  'coordenadas',
#  'latitud',
#  'longitud',
#  'elev',
#  'uom_elev',
#  'ref',
#  'distancia_ref',
#  'direccion_ref',
#  'condicion',
#  'control',
#  'region',
#  'fir',
#  'uso',
#  'trafico',
#  'sna',
#  'concesionado',
#  'provincia',
#  'inhab']

# %%
df_aeropuertos
# Out:
#     local  oaci iata       tipo                       denominacion  \
# 0     ACB   NaN  NaN  Aeródromo       CORONEL BOGADO/AGROSERVICIOS
# 1     ACH   NaN  NaN  Aeródromo                       GENERAL ACHA
# 2     ACM   NaN  NaN  Aeródromo            ARRECIFES/LA CURA MALAL
# 3     ADO  SAWD  PUD  Aeródromo                     PUERTO DESEADO
# 4     ADT   NaN  NaN  Aeródromo  BANDERA/AGROSERVICIOS DOÑA TERESA
# ..    ...   ...  ...        ...                                ...
# 688   YOS  SAZH  OYO  Aeródromo                       TRES ARROYOS
# 689   YPY   NaN  NaN  Aeródromo                             YAPEYÚ
# 690   ZAP  SAHZ  APZ  Aeródromo                             ZAPALA
# 691   ZLM   NaN  NaN  Aeródromo               BELL VILLE/LA ZULEMA
# 692   ZUL  SAZA  NaN  Aeródromo                               AZUL
#
#                 coordenadas    latitud   longitud    elev uom_elev  ...  \
# 0    33°16'20"S  60°34'14"W -60.570660 -33.272260    44.0   Metros  ...
# ...

# %%
df_aeropuertos
# Out:
#     local  oaci iata       tipo                       denominacion  \
# 0     ACB   NaN  NaN  Aeródromo       CORONEL BOGADO/AGROSERVICIOS
# 1     ACH   NaN  NaN  Aeródromo                       GENERAL ACHA
# 2     ACM   NaN  NaN  Aeródromo            ARRECIFES/LA CURA MALAL
# 3     ADO  SAWD  PUD  Aeródromo                     PUERTO DESEADO
# 4     ADT   NaN  NaN  Aeródromo  BANDERA/AGROSERVICIOS DOÑA TERESA
# ..    ...   ...  ...        ...                                ...
# 688   YOS  SAZH  OYO  Aeródromo                       TRES ARROYOS
# 689   YPY   NaN  NaN  Aeródromo                             YAPEYÚ
# 690   ZAP  SAHZ  APZ  Aeródromo                             ZAPALA
# 691   ZLM   NaN  NaN  Aeródromo               BELL VILLE/LA ZULEMA
# 692   ZUL  SAZA  NaN  Aeródromo                               AZUL
#
#                 coordenadas    latitud   longitud    elev uom_elev  ...  \
# 0    33°16'20"S  60°34'14"W -60.570660 -33.272260    44.0   Metros  ...
# ...
