# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/EDVai_DE/blob/main/Sesion_01/NB_Sesion_01_Alexander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
path_github = 'https://raw.githubusercontent.com/alexandergribenchenko/EDVai_DE/main/Sesion_01/data/Utimas%20Desvinculaciones_Row_data.csv'

# %%
# Lectura simpre
df = pd.read_csv(path_github)
df
# Out:
#     Id     Nombre   Apellido        Area Fecha comienzo   Fecha fin Nivel  \
# 0    1     Romina      Brito   Marketing     03/05/2018  12/31/2018    N3
# 1    2      Pedro      Lujan     Compras     03/06/2017  12/31/2021    N3
# 2    3       Juan   Albornoz          IT     06/04/2018  04/30/2019    N4
# 3    4  Sebastian   González     Legales     05/07/2018  05/30/2021    N2
# 4    5     Franco  Rodríguez   Marketing     05/01/2017  11/30/2017    N5
# 5    6   Catalina      Gómez  Producción     04/01/2019  03/31/2022    N2
# 6    7   Anabella  Fernández      Ventas     07/06/2020  03/31/2021    N4
# 7    8  Francesca      López     Compras     01/02/2017  06/30/2021    N3
# 8    9    Nicolas   Martínez          IT     01/04/2021  11/30/2021    N2
# 9   10        Ana       Diaz          IT     03/06/2017  11/30/2020    N4
# 10  11    Roberto      Pérez   Marketing     07/01/2019  04/30/2022    N5
# 11  12       Luis    Sánchez      Ventas     07/13/2020  12/31/2020    N5
# 12  13  Alejandro     Romero          IT     06/01/2020  02/28/2022    N3
# 13  14       Raul     García      Ventas     02/04/2019  03/31/2020    N3
# 14  15     Analia       Sosa     Compras     10/01/2018  11/30/2021    N4
# 15  16     Vanina    Benítez          IT     08/05/2019  04/30/2020    N5
# 16  17  Guillermo    Ramírez          IT     01/06/2020  05/31/2022    N2
# 17  18      Pedro     Torres   Marketing     04/03/2017  12/31/2019    N3
# 18  19      Rocio       Ruiz   Auditoria     02/05/2018  01/30/2021    N4
# 19  20    Marcelo     Flores      Ventas     09/06/2021  05/31/2022    N2
# 20  21   Cristian     Martin     Compras     11/06/2017  12/31/2020    N5
# 21  22     Matias    Bosques      Ventas     12/03/2018  06/30/2021    N4
# 22  23     Camila     Prieto          IT     01/03/2022  07/01/2022    N6
# 23  24    Micaela      Pauls  Producción     01/07/2019  12/31/2021    N6
# 24  25   Carolina   Petersen      Ventas     07/05/2021  02/28/2022    N7
# 25  26     Fabian     Quiroz  Producción     05/07/2018  09/30/2021    N3
# 26  27    Rodrigo    Molinas     Compras     06/03/2019  04/30/2022    N2
# 27  28    Martina   Oliviera  Producción     01/06/2020  06/30/2022    N7
# 28  29      Dante    Martini          IT     03/01/2021  12/31/2021    N4
# 29  30      Diego      Buzos   Auditoria     09/06/2021  06/30/2022    N1
#
#    Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 0            Grupo B                   3        Rango 3        Rango 3
# 1            Grupo B                   3        Rango 2        Rango 2
# 2            Grupo C                   4        Rango 4        Rango 4
# 3            Grupo A                   4        Rango 2        Rango 2
# 4            Grupo C                   6        Rango 5        Rango 4
# 5            Grupo B                   4        Rango 2        Rango 2
# 6            Grupo A                   3        Rango 4        Rango 4
# 7            Grupo A                   4        Rango 3        Rango 3
# 8            Grupo C                   6        Rango 3        Rango 3
# 9            Grupo A                   3        Rango 3        Rango 3
# 10           Grupo B                   5        Rango 5        Rango 5
# 11           Grupo C                   5        Rango 6        Rango 6
# 12           Grupo A                   3        Rango 4        Rango 3
# 13           Grupo C                   6        Rango 3        Rango 3
# 14           Grupo A                   4        Rango 4        Rango 4
# 15           Grupo C                   5        Rango 6        Rango 6
# 16           Grupo A                   3        Rango 2        Rango 2
# 17           Grupo B                   4        Rango 3        Rango 3
# 18           Grupo A                   4        Rango 4        Rango 5
# 19           Grupo C                   6        Rango 2        Rango 2
# 20           Grupo C                   4        Rango 6        Rango 5
# 21           Grupo B                   3        Rango 4        Rango 4
# 22           Grupo C                   6        Rango 6        Rango 6
# 23           Grupo A                   5        Rango 6        Rango 6
# 24           Grupo B                   4        Rango 6        Rango 6
# 25           Grupo B                   3        Rango 2        Rango 3
# 26           Grupo A                   4        Rango 2        Rango 2
# 27           Grupo A                   4        Rango 6        Rango 6
# 28           Grupo C                   6        Rango 3        Rango 3
# 29           Grupo C                   3        Rango 1        Rango 1
#
#     Manager Realizo Cursos
# 0         1             SI
# 1         2             SI
# 2         5             NO
# 3         3             SI
# 4         1             SI
# 5         4             NO
# 6         8             NO
# 7         2             SI
# 8         5             SI
# 9         7             NO
# 10        9             SI
# 11        8             NO
# 12        7             SI
# 13        8             SI
# 14        2             NO
# 15        5             SI
# 16        7             NO
# 17        9             SI
# 18       10             NO
# 19        8             SI
# 20        2             SI
# 21        8             SI
# 22        5             NO
# 23        4             SI
# 24        8             SI
# 25        6             SI
# 26        2             SI
# 27        6             SI
# 28        5             NO
# 29       10             SI

# %%
df['Fecha comienzo'] = pd.to_datetime(df['Fecha comienzo'], format='%m/%d/%Y')
df['Fecha fin'] = pd.to_datetime(df['Fecha fin'], format='%m/%d/%Y')
df['dias_total'] = (df['Fecha fin']-df['Fecha comienzo']).dt.days
df['Manager'] = df['Manager'].astype('str')
df = df.sort_values(by='dias_total', ascending=True)
df
# Out:
#     Id     Nombre   Apellido        Area Fecha comienzo  Fecha fin Nivel  \
# 11  12       Luis    Sánchez      Ventas     2020-07-13 2020-12-31    N5
# 22  23     Camila     Prieto          IT     2022-01-03 2022-07-01    N6
# 4    5     Franco  Rodríguez   Marketing     2017-05-01 2017-11-30    N5
# 24  25   Carolina   Petersen      Ventas     2021-07-05 2022-02-28    N7
# 19  20    Marcelo     Flores      Ventas     2021-09-06 2022-05-31    N2
# 6    7   Anabella  Fernández      Ventas     2020-07-06 2021-03-31    N4
# 15  16     Vanina    Benítez          IT     2019-08-05 2020-04-30    N5
# 29  30      Diego      Buzos   Auditoria     2021-09-06 2022-06-30    N1
# 0    1     Romina      Brito   Marketing     2018-03-05 2018-12-31    N3
# 28  29      Dante    Martini          IT     2021-03-01 2021-12-31    N4
# 8    9    Nicolas   Martínez          IT     2021-01-04 2021-11-30    N2
# 2    3       Juan   Albornoz          IT     2018-06-04 2019-04-30    N4
# 13  14       Raul     García      Ventas     2019-02-04 2020-03-31    N3
# 12  13  Alejandro     Romero          IT     2020-06-01 2022-02-28    N3
# 16  17  Guillermo    Ramírez          IT     2020-01-06 2022-05-31    N2
# 27  28    Martina   Oliviera  Producción     2020-01-06 2022-06-30    N7
# 21  22     Matias    Bosques      Ventas     2018-12-03 2021-06-30    N4
# 17  18      Pedro     Torres   Marketing     2017-04-03 2019-12-31    N3
# 10  11    Roberto      Pérez   Marketing     2019-07-01 2022-04-30    N5
# 26  27    Rodrigo    Molinas     Compras     2019-06-03 2022-04-30    N2
# 23  24    Micaela      Pauls  Producción     2019-01-07 2021-12-31    N6
# 18  19      Rocio       Ruiz   Auditoria     2018-02-05 2021-01-30    N4
# 5    6   Catalina      Gómez  Producción     2019-04-01 2022-03-31    N2
# 3    4  Sebastian   González     Legales     2018-05-07 2021-05-30    N2
# 20  21   Cristian     Martin     Compras     2017-11-06 2020-12-31    N5
# 14  15     Analia       Sosa     Compras     2018-10-01 2021-11-30    N4
# 25  26     Fabian     Quiroz  Producción     2018-05-07 2021-09-30    N3
# 9   10        Ana       Diaz          IT     2017-03-06 2020-11-30    N4
# 7    8  Francesca      López     Compras     2017-01-02 2021-06-30    N3
# 1    2      Pedro      Lujan     Compras     2017-03-06 2021-12-31    N3
#
#    Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 11           Grupo C                   5        Rango 6        Rango 6
# 22           Grupo C                   6        Rango 6        Rango 6
# 4            Grupo C                   6        Rango 5        Rango 4
# 24           Grupo B                   4        Rango 6        Rango 6
# 19           Grupo C                   6        Rango 2        Rango 2
# 6            Grupo A                   3        Rango 4        Rango 4
# 15           Grupo C                   5        Rango 6        Rango 6
# 29           Grupo C                   3        Rango 1        Rango 1
# 0            Grupo B                   3        Rango 3        Rango 3
# 28           Grupo C                   6        Rango 3        Rango 3
# 8            Grupo C                   6        Rango 3        Rango 3
# 2            Grupo C                   4        Rango 4        Rango 4
# 13           Grupo C                   6        Rango 3        Rango 3
# 12           Grupo A                   3        Rango 4        Rango 3
# 16           Grupo A                   3        Rango 2        Rango 2
# 27           Grupo A                   4        Rango 6        Rango 6
# 21           Grupo B                   3        Rango 4        Rango 4
# 17           Grupo B                   4        Rango 3        Rango 3
# 10           Grupo B                   5        Rango 5        Rango 5
# 26           Grupo A                   4        Rango 2        Rango 2
# 23           Grupo A                   5        Rango 6        Rango 6
# 18           Grupo A                   4        Rango 4        Rango 5
# 5            Grupo B                   4        Rango 2        Rango 2
# 3            Grupo A                   4        Rango 2        Rango 2
# 20           Grupo C                   4        Rango 6        Rango 5
# 14           Grupo A                   4        Rango 4        Rango 4
# 25           Grupo B                   3        Rango 2        Rango 3
# 9            Grupo A                   3        Rango 3        Rango 3
# 7            Grupo A                   4        Rango 3        Rango 3
# 1            Grupo B                   3        Rango 2        Rango 2
#
#    Manager Realizo Cursos  dias_total
# 11       8             NO         171
# 22       5             NO         179
# 4        1             SI         213
# 24       8             SI         238
# 19       8             SI         267
# 6        8             NO         268
# 15       5             SI         269
# 29      10             SI         297
# 0        1             SI         301
# 28       5             NO         305
# 8        5             SI         330
# 2        5             NO         330
# 13       8             SI         421
# 12       7             SI         637
# 16       7             NO         876
# 27       6             SI         906
# 21       8             SI         940
# 17       9             SI        1002
# 10       9             SI        1034
# 26       2             SI        1062
# 23       4             SI        1089
# 18      10             NO        1090
# 5        4             NO        1095
# 3        3             SI        1119
# 20       2             SI        1151
# 14       2             NO        1156
# 25       6             SI        1242
# 9        7             NO        1365
# 7        2             SI        1640
# 1        2             SI        1761

# %%
df.head(2)
# Out:
#     Id  Nombre Apellido    Area Fecha comienzo  Fecha fin Nivel  \
# 11  12    Luis  Sánchez  Ventas     2020-07-13 2020-12-31    N5
# 22  23  Camila   Prieto      IT     2022-01-03 2022-07-01    N6
#
#    Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 11           Grupo C                   5        Rango 6        Rango 6
# 22           Grupo C                   6        Rango 6        Rango 6
#
#     Manager Realizo Cursos  dias_total
# 11        8             NO         171
# 22        5             NO         179

# %%
import pandas as pd
from scipy.stats import f_oneway

# %%
grupos = [df[df['Grupo recruitment'] == grupo]['dias_total'] for grupo in df['Grupo recruitment'].unique()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Grupo recruitment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-2bdeb8091b77> in <module>
# ----> 1 grupos = [df[df['Grupo recruitment'] == grupo]['dias_total'] for grupo in df['Grupo recruitment'].unique()]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Grupo recruitment'

# %%
y_grafica = 'Manager'

# %%
# creating boxplot
sns.boxplot(y=y_grafica, x='dias_total', data=df)
  
# adding data points
sns.stripplot(y= y_grafica, x='dias_total', data=df)
# display plot
plt.show()

# %%
import pandas as pd
from scipy.stats import f_oneway

# Crea un dataframe con una variable categórica y una variable numérica
df = pd.DataFrame({'categoria': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'numerica': [10, 20, 30, 15, 25, 35]})

# Agrupa los datos por la variable categórica
grupos = [df[df['categoria'] == categoria]['numerica'] for categoria in df['categoria'].unique()]

# Realiza el análisis de varianza
f, p = f_oneway(*grupos)
print('F-value:', f)
print('p-value:', p)
# Out:
# F-value: 16.0
# p-value: 0.025094573304390855

# %%
type(df.dias_total[0])
# Out:
# numpy.int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     object
#  5   Fecha fin           30 non-null     object
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 3.2+ KB

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

fig, ax = plt.subplots(figsize=(10, 5))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=1920, xmax=2010)
fig.tight_layout()

# %%
fig_01, ax_01 = plt.subplots(figsize=(10, 5))

sns.countplot(data=df, y="Manager",  order=df.Manager.value_counts().sort_values(ascending=False).index, color=sns.color_palette("Set1")[1], ax=ax_01)



ax_01.set_title("Número de observaciones por día")
ax_01.set_xlabel("Día")
ax_01.set_ylabel("Número de observaciones")

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear una figura y un conjunto de subplots de 2x2
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Crear un countplot en cada subplot
sns.countplot(x="day", data=tips, ax=axes[0, 0])
sns.countplot(x="time", data=tips, ax=axes[0, 1])
sns.countplot(x="sex", data=tips, ax=axes[1, 0])
sns.countplot(x="smoker", data=tips, ax=axes[1, 1])

# Ajustar los títulos y etiquetas de los ejes en cada subplot
axes[0, 0].set_title("Countplot de días")
axes[0, 1].set_title("Countplot de tiempo")
axes[1, 0].set_title("Countplot de género")
axes[1, 1].set_title("Countplot de fumadores")

axes[0, 0].set_xlabel("Día")
axes[0, 1].set_xlabel("Tiempo")
axes[1, 0].set_xlabel("Género")
axes[1, 1].set_xlabel("Fumador")

axes[0, 0].set_ylabel("Número de observaciones")
axes[0, 1].set_ylabel("Número de observaciones")
axes[1, 0].set_ylabel("Número de observaciones")
axes[1, 1].set_ylabel("Número de observaciones")

# Ajustar el espaciado entre subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Mostrar el gráfico
plt.show()
